# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %% [markdown]
# # 코로나 + 주말농장

# %%
df1 = pd.read_excel("/content/drive/MyDrive/data/네이버뉴스_오산시_2021-10-04_13시26분.xlsx")
df1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-eec019019774> in <module>()
# ----> 1 df1 = pd.read_excel("/content/drive/MyDrive/data/네이버뉴스_오산시_2021-10-04_13시26분.xlsx")
#       2 df1
#
# NameError: name 'pd' is not defined

# %%
df1.dropna(inplace = True)

# %%
df1.drop_duplicates(['title'], keep = 'last')

# %%
import numpy as np
df_1 = np.array(df1['title'].tolist())
df1 = " ".join(df_1)

# %%
df1

# %%
# !pip install konlpy

# %%
from konlpy.tag import Okt 
twitter_tag = Okt()
def my_tokenizer(doc):
    return [token for token, pos in twitter_tag.pos(doc) if pos in ['Noun']]

df1_doc = my_tokenizer(df1)

# %%
print(df1_doc, end = '')

# %%
#빈도 사전 만들기
df_cnt1 = {}
for word in df1_doc:
    df_cnt1[word] = df_cnt1.get(word, 0) + 1

# %%
sorted_word_count = sorted(df_cnt1, key= df_cnt1.get, reverse=True)
#sorted_word_count 

print("빈도수가 많은 상위 30개:")
for key in sorted_word_count[:30]: 
    print(f'{repr(key)}: {df_cnt1[key]}', end=', ')

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf

# %%
#불용어 사전 정리 후 재정의
my_stopword = ['농장','주말','위','명','코로나','시청률','오케이 광자매','주말드라마 한번다녀왔습니다','도','속','등','오케이','광자매','광','자매','로','홍은희','전혜빈','원희','차','농','청','토','확','중','철','곳','재','조사','법',
               '수','세','기','개','제','축구','프로그램','백신','슈퍼맨','것','윤주상','및','외','주말드라마 한번다녀왔습니다','한번다녀왔습니다 지상파'] 
result = [word for word in df1_doc if word not in my_stopword] 

#불용어 사전 제거 후 단어 빈도 사전 만들기
df_cnt1 = {}
for word in result:
    df_cnt1[word] = df_cnt1.get(word, 0) + 1

sorted_word_count = sorted(df_cnt1, key= df_cnt1.get, reverse=True)
#sorted_word_count 

print("빈도수가 많은 상위 30개:")
for key in sorted_word_count[:30]: 
    print(f'{repr(key)}: {df_cnt1[key]}', end=', ')

# %%
import nltk

# %%
ko = nltk.Text(result, name='코로나&주말농장')

# %%
data = ko.vocab().most_common(300)
data

# %%
from PIL import Image

# %%
df_mask = np.array(Image.open('/content/drive/MyDrive/오산시/이파리리.png'))
df_mask

# %%
from wordcloud import WordCloud

# %%
wc = WordCloud(background_color='white', max_words=150, stopwords=my_stopword, mask=df_mask,font_path='NanumBarunGothic')
wc = wc.generate(df1)  # 데이터 불러와서 워드클라우드 옵션 지정
wc

# %%
plt.figure(figsize=(16,16))
plt.imshow(wc)
plt.axis('off')  # 축 없이!
plt.show()

# %% [markdown]
# # 주말농장

# %%
df2 = pd.read_excel('/content/drive/MyDrive/오산시/네이버뉴스_주말농장.xlsx')
df2
# Out:
#      Unnamed: 0  ...                                                url
# 0             0  ...  http://www.newsis.com/view/?id=NISX20210923_00...
# 1             1  ...                             https://bit.ly/3CNqewu
# 2             2  ...  http://weekly.chosun.com/client/news/viw.asp?n...
# 3             3  ...  http://www.babytimes.co.kr/news/articleView.ht...
# 4             4  ...  http://www.jejutwn.com/news/article.html?no=91929
# ..          ...  ...                                                ...
# 995         995  ...  http://www.kgdm.co.kr/news/articleView.html?id...
# 996         996  ...  http://www.viva100.com/main/view.php?key=20200...
# 997         997  ...  http://www.goodmorningcc.com/news/articleView....
# 998         998  ...  http://sports.khan.co.kr/news/sk_index.html?ar...
# 999         999  ...  http://www.topstarnews.net/news/articleView.ht...
#
# [1000 rows x 3 columns]

# %%
df2.dropna(inplace = True)
df2.drop_duplicates(['title'], keep = 'last')
# Out:
#      Unnamed: 0  ...                                                url
# 0             0  ...
# ...

# %%
from konlpy.tag import Okt 
twitter_tag = Okt()
def my_tokenizer(doc):
    return [token for token, pos in twitter_tag.pos(doc) if pos in ['Noun']]

df2_doc = my_tokenizer(df2)

# %%
print(df1_doc, end = '')
# Out:
# ['특허청', '코로나', '로', '주말', '농장', '집콕', '시대', '경북', '코로나', '확산', '세', '급증', '주말', '여', '명', '확', '진자', '발생', '특허', '기술', '주말', '농장', '집콕', '시대', '가정', '용', '식물', '재배', '기', '관련', '특허', '출원', '급증', '주말', '농장', '집콕', '시대', '특허', '기술', '주말', '농장', '집콕', '시대', '린다', '퇴직', '전', '평', '주말', '농장', '연습', '주말', '기준', '최', '확진', '추석', '연휴', '최대', '고비', '일산', '호수', '공원', '주말', '농산물', '새벽', '장터', '인기', '주말', '쉼표', '경기', '연구원', '귀농', '귀촌', '도시', '인근', '실습', '농장', '적응력', '예비', '귀농', '위', '도시', '실습', '농장', '필요', '숨통', '주말', '텃밭', '도시', '거리', '두기', '안성시', '일죽면', '공직자', '주말', '이용', '농촌', '일손', '도', '델타', '변', '대이동', '시작', '중', '대본', '중부', '시장', '강북', '도우미', '노래', '부암', '주민', '센터', '검진', '동작', '버드', '바', '구로', '알로하', '창원', '중앙', '역', '등', '코로나', '하모니', '어서', '부부', '꿈', '희망', '농장', '부', '월성', '원자력', '본부', '주말', '농장', '운영', '원전', '안전성', '신뢰', '확보', '효과', '톡톡', '내포신도시', '주말', '농장', '인근', '불법', '정차', '해소', '목포', '삼향동', '주말', '농장', '개장', '농협', '은행', '부산', '본부', '주말', '농장', '개장', '익산시', '코로나', '블루', '극복', '주말'
# ...

# %%
#빈도 사전 만들기
df_cnt2 = {}
for word in df2_doc:
    df_cnt2[word] = df_cnt2.get(word, 0) + 1

# %%
sorted_word_count = sorted(df_cnt2, key= df_cnt2.get, reverse=True)
#sorted_word_count 

print("빈도수가 많은 상위 30개:")
for key in sorted_word_count[:30]: 
    print(f'{repr(key)}: {df_cnt2[key]}', end=', ')
# Out:
# 빈도수가 많은 상위 30개:
# '농장': 865, '주말': 787, '분양': 195, '개장': 123, '체험': 69, '텃밭': 67, '농업': 67, '농지': 66, '농협': 57, '시민': 56, '투기': 55, '모집': 50, '가족': 44, '마을': 43, '친환경': 42, '도': 39, '신청': 38, '접수': 37, '귀농': 36, '공무원': 36, '귀촌': 35, '삼향동': 35, '수확': 34, '무료': 34, '농부': 33, '목포시': 31, '운영': 30, '도시': 30, '등': 30, '법': 28,

# %%
#불용어 사전 정리 후 재정의
my_stopword = ['용','삼','김민경','살','급','관','나혼산','때','내','나','달','빛','윌리엄','벤틀리','김한규','송병철','포토','회','배우자','첫','물','부','남','으리','배','신당','박영','사이버대'] 
result = [word for word in df2_doc if word not in my_stopword] 

#불용어 사전 제거 후 단어 빈도 사전 만들기
df_cnt2 = {}
for word in result:
    df_cnt2[word] = df_cnt2.get(word, 0) + 1

sorted_word_count = sorted(df_cnt2, key= df_cnt2.get, reverse=True)
#sorted_word_count 

print("빈도수가 많은 상위 30개:")
for key in sorted_word_count[:30]: 
    print(f'{repr(key)}: {df_cnt2[key]}', end=', ')
# Out:
# 빈도수가 많은 상위 30개:
# '농장': 865, '주말': 787, '분양': 195, '개장': 123, '체험': 69, '텃밭': 67, '농업': 67, '농지': 66, '농협': 57, '시민': 56, '투기': 55, '모집': 50, '가족': 44, '마을': 43, '친환경': 42, '도': 39, '신청': 38, '접수': 37, '귀농': 36, '공무원': 36, '귀촌': 35, '삼향동': 35, '수확': 34, '무료': 34, '농부': 33, '목포시': 31, '운영': 30, '도시': 30, '등': 30, '법': 28,

# %%
ko = nltk.Text(result, name='주말농장')

# %%
data2 = ko.vocab().most_common(300)
data2
# Out:
# [('농장', 865),
#  ('주말', 787),
#  ('분양', 195),
#  ('개장', 123),
#  ('체험', 69),
#  ('텃밭', 67),
#  ('농업', 67),
#  ('농지', 66),
#  ('농협', 57),
#  ('시민', 56),
#  ('투기', 55),
#  ('모집', 50),
#  ('가족', 44),
#  ('마을', 43),
#  ('친환경', 42),
#  ('도', 39),
#  ('신청', 38),
#  ('접수', 37),
#  ('귀농', 36),
#  ('공무원', 36),
#  ('귀촌', 35),
#  ('삼향동', 35),
#  ('수확', 34),
#  ('무료', 34),
#  ('농부', 33),
#  ('목포시', 31),
#  ('운영', 30),
#  ('도시', 30),
#  ('등', 30),
#  ('법', 28),
#  ('센터', 27),
#  ('재배', 26),
#  ('교육', 26),
#  ('지역', 26),
#  ('인천', 26),
#  ('환경', 26),
#  ('지원', 25),
#  ('부산', 24),
#  ('영종도', 24),
#  ('대구', 24),
#  ('농사', 22),
#  ('송치', 22),
#  ('산양', 22),
#  ('목적', 21),
#  ('전원', 21),
#  ('도시농업', 21),
#  ('땅', 21),
#  ('공단', 21),
#  ('전남대', 20),
#  ('사업', 20),
#  ('소식', 20),
#  ('청도군', 20),
#  ('함양', 20),
#  ('위', 19),
#  ('전남', 19),
#  ('캠핑', 19),
#  ('박물관', 18),
#  ('토지', 18),
#  ('동물농장', 18),
#  ('추가', 18),
#  ('의혹', 18),
#  ('코로나', 17),
#  ('취득', 17),
#  ('인기', 17),
#  ('실습', 17),
# ...

# %%
from wordcloud import WordCloud

wc = WordCloud(background_color='white', max_words=150, stopwords=my_stopword, mask=df_mask,font_path='NanumBarunGothic')
wc = wc.generate(df2)  # 데이터 불러와서 워드클라우드 옵션 지정
wc

# %%
plt.figure(figsize=(16,16))
plt.imshow(wc)
plt.axis('off')  # 축 없이!
plt.show()

# %% [markdown]
# # 코로나 + 임대농장

# %%
df3 = pd.read_excel('/content/drive/MyDrive/오산시/네이버뉴스_코로나+임대농장.xlsx')
df3
# Out:
#      Unnamed: 0  ...                                                url
# 0             0  ...   http://www.kukinews.com/newsView/kuk202109040006
# 1             1  ...  http://www.yonhapnewstv.co.kr/MYH2021090301690...
# 2             2  ...    http://www.newspim.com/news/view/20210924000602
# 3             3  ...  http://www.movist.com/movist3d/view.asp?type=7...
# 4             4  ...  http://www.dynews.co.kr/news/articleView.html?...
# ..          ...  ...                                                ...
# 995         995  ...  http://ilyo.co.kr/?ac=article_view&entry_id=37...
# 996         996  ...  http://www.ybsn.tv/news/articleView.html?idxno...
# 997         997  ...  http://moneys.mt.co.kr/news/mwView.php?no=2020...
# 998         998  ...  https://biz.chosun.com/site/data/html_dir/2020...
# 999         999  ...  http://moneys.mt.co.kr/news/mwView.php?no=2020...
#
# [1000 rows x 3 columns]

# %%
df3.dropna(inplace = True)
df3.drop_duplicates(['title'], keep = 'last')
# Out:
#      Unnamed: 0  ...                                                url
# 0             0  
# ...

# %%
from konlpy.tag import Okt 
twitter_tag = Okt()
def my_tokenizer(doc):
    return [token for token, pos in twitter_tag.pos(doc) if pos in ['Noun']]

df3_doc = my_tokenizer(df3)

# %%
print(df3_doc, end = '')
# Out:
# ['의령', '소식', '코로나', '청정', '지역', '명성', '회복', '앞장', '하모니', '어서', '부부', '꿈', '희망', '농장', '부', '출발', '에뛰드', '이창', '규', '아모레', '손가락', '유라시아', '캠핑', '로드', '개척', '영준', '서울', '백석', '예술', '대학교', '교수', '프리즘', '귀농', '청년', '농부가', '늘', '미래', '블루', '오션', '동부', '경남', '김해시', '청년', '농업인', '경영', '실습', '임대', '농장', '준공', '김해시', '브리핑', '청년', '농업인', '경영', '실습', '임대', '농장', '준공', '등', '브렉', '시트', '코로나', '위기', '속', '영국', '농업', '선택', '다각', '미래', '지향', '독일', '코로나', '시대', '도심', '속', '정원', '클라인', '인기', '홍천군', '농기', '임대', '사업', '소', '농촌', '일손', '돕기', '활동', '전개', '홍천군', '농기', '임대', '사업', '소', '농촌', '일손', '돕기', '활동', '전개', '코로나', '시대', '나', '힐링', '공간', '도심', '정원', '클라인', '특집', '김천시', '현장', '고객', '중심', '농촌', '지도', '사업', '가동', '미래', '농업', '선도', '착착', '영암군', '청년', '경영', '실습', '임대', '농장', '임차', '추가', '모집', '상주시', '귀농', '귀촌', '임대주택', '입', '주자', '설명', '회', '농장', '탐방', '충북', '옥천', '옥천', '목장', '상주시', '귀농', '귀촌', '임대주택', '입', '주자', '설명', '회', '호주', '농장', '박씨', '한국', '최저임금', '여기', '입', '학교', '그', '시골', '교육', '이주', '간', '이유'
# ...

# %%
#빈도 사전 만들기
df_cnt3 = {}
for word in df3_doc:
    df_cnt3[word] = df_cnt3.get(word, 0) + 1

# %%
sorted_word_count = sorted(df_cnt3, key= df_cnt3.get, reverse=True)
#sorted_word_count 

print("빈도수가 많은 상위 30개:")
for key in sorted_word_count[:30]: 
    print(f'{repr(key)}: {df_cnt3[key]}', end=', ')
# Out:
# 빈도수가 많은 상위 30개:
# '코로나': 128, '농업': 120, '농장': 81, '스마트': 69, '군수': 69, '귀농': 59, '지원': 57, '청년': 56, '사업': 56, '농촌': 48, '도시': 46, '미래': 37, '현장': 33, '등': 32, '센터': 32, '귀촌': 31, '예산': 31, '경제': 30, '조성': 29, '지역': 26, '경영': 26, '외국인': 26, '신년사': 26, '것': 26, '산업': 26, '소식': 25, '농': 25, '인터뷰': 25, '혁신': 25, '추진': 25,

# %%
#불용어 사전 정리 후 재정의
my_stopword = ['농장','주말','위','명','코로나','시청률','오케이 광자매','주말드라마 한번다녀왔습니다','도','속','등','오케이','광자매','광','자매','로','홍은희','전혜빈','원희','차','농','청','토','확','중','철','곳','재','조사','법',
               '수','세','기','개','제','축구','프로그램','백신','슈퍼맨','것','윤주상','및','외','주말드라마 한번다녀왔습니다','한번다녀왔습니다 지상파'] 
result = [word for word in df3_doc if word not in my_stopword] 

#불용어 사전 제거 후 단어 빈도 사전 만들기
df_cnt3 = {}
for word in result:
    df_cnt3[word] = df_cnt3.get(word, 0) + 1

sorted_word_count = sorted(df_cnt3, key= df_cnt3.get, reverse=True)
#sorted_word_count 

print("빈도수가 많은 상위 30개:")
for key in sorted_word_count[:30]: 
    print(f'{repr(key)}: {df_cnt3[key]}', end=', ')
# Out:
# 빈도수가 많은 상위 30개:
# '농업': 120, '스마트': 69, '군수': 69, '귀농': 59, '지원': 57, '청년': 56, '사업': 56, '농촌': 48, '도시': 46, '미래': 37, '현장': 33, '센터': 32, '귀촌': 31, '예산': 31, '경제': 30, '조성': 29, '지역': 26, '경영': 26, '외국인': 26, '신년사': 26, '산업': 26, '소식': 25, '인터뷰': 25, '혁신': 25, '추진': 25, '임대': 23, '위기': 23, '시대': 23, '사랑': 23, '농부': 23,

# %%
ko = nltk.Text(result, name='코로나+임대농장')

# %%
data3 = ko.vocab().most_common(300)
data3
# Out:
# [('농업', 120),
#  ('스마트', 69),
#  ('군수', 69),
#  ('귀농', 59),
#  ('지원', 57),
#  ('청년', 56),
#  ('사업', 56),
#  ('농촌', 48),
#  ('도시', 46),
#  ('미래', 37),
#  ('현장', 33),
#  ('센터', 32),
#  ('귀촌', 31),
#  ('예산', 31),
#  ('경제', 30),
#  ('조성', 29),
#  ('지역', 26),
#  ('경영', 26),
#  ('외국인', 26),
#  ('신년사', 26),
#  ('산업', 26),
#  ('소식', 25),
#  ('인터뷰', 25),
#  ('혁신', 25),
#  ('추진', 25),
#  ('임대', 23),
#  ('위기', 23),
#  ('시대', 23),
#  ('사랑', 23),
#  ('농부', 23),
#  ('기술', 23),
#  ('농업인', 22),
#  ('확보', 22),
#  ('창업', 21),
#  ('농협', 21),
#  ('특별', 21),
#  ('올해', 21),
#  ('나눔', 20),
#  ('시민', 20),
#  ('경북', 20),
#  ('한국', 19),
#  ('농식품부', 19),
#  ('성과', 19),
#  ('방역', 19),
#  ('도약', 19),
#  ('행정', 19),
#  ('경남', 18),
#  ('정부', 18),
#  ('대상', 18),
#  ('계약', 18),
#  ('재난', 17),
#  ('박차', 17),
#  ('영양', 17),
#  ('살기', 17),
#  ('실습', 16),
#  ('구제역', 16),
#  ('장흥', 16),
#  ('브리핑', 15),
#  ('농가', 15),
#  ('고양시', 15),
#  ('행복', 15),
#  ('친환경', 15),
#  ('안전', 15),
#  ('주요', 15),
#  ('경쟁력', 15),
# ...

# %%
from wordcloud import WordCloud

wc = WordCloud(background_color='white', max_words=150, stopwords=my_stopword, mask=df_mask,font_path='NanumBarunGothic')
wc = wc.generate(df3)  # 데이터 불러와서 워드클라우드 옵션 지정
wc

# %%
plt.figure(figsize=(16,16))
plt.imshow(wc)
plt.axis('off')  # 축 없이!
plt.show()

# %% [markdown]
# # 20대 + 농장

# %%
df4 = pd.read_excel("/content/drive/MyDrive/data/네이버뉴스_20대+농장_2021-09-28_21시25분.xlsx")
df4
# Out:
#      Unnamed: 0  ...                                                url
# 0             0  ...  http://www.knnews.co.kr/news/articleView.php?i...
# 1             1  ...  http://www.ohmynews.com/NWS_Web/View/at_pg.asp...
# 2             2  ...  http://news.tvchosun.com/site/data/html_dir/20...
# 3             3  ...  http://sports.chosun.com/news/ntype.htm?id=202...
# 4             4  ...  http://www.aflnews.co.kr/news/articleView.html...
# ..          ...  ...                                                ...
# 811         825  ...  http://kr.people.com.cn/n3/2021/0806/c208059-9...
# ...

# %%
from konlpy.tag import Okt 
twitter_tag = Okt()
def my_tokenizer(doc):
    return [token for token, pos in twitter_tag.pos(doc) if pos in ['Noun']]

df4_doc = my_tokenizer(df4)

# %%
print(df4_doc, end = '')
# Out:
# ['창원', '청년', '농업인', '스타', '탐방', '농장', '대표', '정은선', '농장', '동물', '행복', '논', '사람', '저', '좀', '사이드', '울산', '항', '밀', '입국', '미얀마', '선원', '강원도', '농장', '체포', '이상준', '모발', '이식', '깜짝', '고백', '탈모', '진행', '신기루', '탈모', '의심', '와카', '남', '한우', '학과', '버섯', '학과', '창업', '대신', '창농', '개', '식용', '금지', '대통령', '발언', '동물', '단체', '환영', '실질', '대책', '마련', '가을', '감성', '줄', '연극', '무대', '셋', '주말', '농장', '빚', '대도', '인', '플루', '아시아', '세로', '베트남', '기업', '실현', '영상', '평생', '직업', '교육', '대학', '길', '이야기', '세상', '논쟁', '개', '가족', '식용', '당선', '방역', '정책', '법적', '대응', '탐방', '자매', '최고', '한우', '육종', '억대', '농장', '억대', '농장', '하늘', '하나', '자매', '우리나라', '최초', '농장', '꿈', '김영철', '바퀴', '수원', '여행', '화장실', '박물관', '해우소', '식용', '꽃', '허브', '농장', '화제', '워킹맘', '비정규직', '창업', '꼭', '평창', '마지기', '농장', '자연', '경관', '포토', '스팟', '명소', '각광', '포천', '양돈', '농가', '분뇨', '탱크', '청소', '농장', '주', '아들', '평행선', '개', '식용', '논란', '개', '농장', '한국', '보신탕', '금지법', '발의', '동물', '단체', '개', '농장', '주도', '폐업', '개', '식용', '사슬', '강소', '농', '농촌', '총각', '억대', '부농', '실현', '화제',
# ...

# %%
#빈도 사전 만들기
df_cnt4 = {}
for word in df4_doc:
    df_cnt4[word] = df_cnt4.get(word, 0) + 1

# %%
sorted_word_count = sorted(df_cnt4, key= df_cnt4.get, reverse=True)
#sorted_word_count 

print("빈도수가 많은 상위 30개:")
for key in sorted_word_count[:30]: 
    print(f'{repr(key)}: {df_cnt4[key]}', end=', ')
# Out:
# 빈도수가 많은 상위 30개:
# '농장': 220, '청년': 62, '명': 58, '대표': 47, '외국인': 40, '농업': 40, '여성': 33, '개': 31, '농촌': 29, '노동자': 29, '농부': 28, '진드기': 27, '야생': 26, '귀농': 26, '등': 25, '사망': 24, '근로자': 23, '코로나': 23, '감염': 19, '국내': 19, '호주': 18, '첫': 18, '미래': 18, '실종': 17, '국회': 17, '돼지': 16, '세': 16, '농업인': 15, '주': 15, '농': 15,

# %%
#불용어 사전 정리 후 재정의
my_stopword = ['살해','20대','와카남','농장','주말','위','명','코로나','사망','외국인','노동자','실종','도','속','등','근로자','호주','영상','3명','로','충남','물린','전염','차','농','청','토','확','중','철','곳','재','조사','법','확진','농장서','구속','실종된','연쇄살인','용의자','사고','피해','여성시신','입건','탈모',
               '수','세','기','개','제','위한','프로그램','백신','식용','것','종합','및','외','여성','남성','검거','숨져','부산','브리핑','숨진','발견','워킹홀리데이','야생진드기','관련','2명','베트남','동물농장','대표','출마 선언','동물 농장','잇따라','붙잡혀','동물농장','여성 시신','여성시신','Y교회','여성시신'] 
result = [word for word in df4_doc if word not in my_stopword] 

#불용어 사전 제거 후 단어 빈도 사전 만들기
df_cnt4 = {}
for word in result:
    df_cnt4[word] = df_cnt4.get(word, 0) + 1

sorted_word_count = sorted(df_cnt4, key= df_cnt4.get, reverse=True)
#sorted_word_count 

print("빈도수가 많은 상위 30개:")
for key in sorted_word_count[:30]: 
    print(f'{repr(key)}: {df_cnt4[key]}', end=', ')
# Out:
# 빈도수가 많은 상위 30개:
# '청년': 62, '농업': 40, '농촌': 29, '농부': 28, '진드기': 27, '야생': 26, '귀농': 26, '감염': 19, '국내': 19, '첫': 18, '미래': 18, '국회': 17, '돼지': 16, '농업인': 15, '주': 15, '현장': 15, '귀촌': 15, '사람': 14, '꿈': 14, '농사': 14, '버섯': 13, '창업': 13, '농막': 13, '집': 13, '교육': 12, '최고': 12, '투기': 12, '의': 12, '뉴스': 12, '남': 11,

# %%
ko = nltk.Text(result, name='20대+농장')

# %%
data4 = ko.vocab().most_common(150)
data4
# Out:
# [('청년', 62),
#  ('농업', 40),
#  ('농촌', 29),
#  ('농부', 28),
#  ('진드기', 27),
#  ('야생', 26),
#  ('귀농', 26),
#  ('감염', 19),
#  ('국내', 19),
#  ('첫', 18),
#  ('미래', 18),
#  ('국회', 17),
#  ('돼지', 16),
#  ('농업인', 15),
#  ('주', 15),
#  ('현장', 15),
#  ('귀촌', 15),
#  ('사람', 14),
#  ('꿈', 14),
#  ('농사', 14),
#  ('버섯', 13),
#  ('창업', 13),
#  ('농막', 13),
#  ('집', 13),
#  ('교육', 12),
#  ('최고', 12),
#  ('투기', 12),
#  ('의', 12),
#  ('뉴스', 12),
#  ('남', 11),
#  ('이야기', 11),
#  ('한국', 11),
#  ('산업', 11),
#  ('오늘', 11),
#  ('식품', 11),
#  ('더', 11),
#  ('와카', 10),
#  ('최초', 10),
#  ('채', 10),
#  ('생산', 10),
#  ('뱀', 10),
#  ('성공', 10),
#  ('전', 10),
#  ('의원', 10),
#  ('사', 10),
#  ('홍성', 10),
#  ('세계', 10),
#  ('추가', 10),
#  ('감염병', 10),
#  ('발생', 10),
#  ('계', 10),
#  ('의심', 9),
#  ('인', 9),
#  ('아들', 9),
#  ('체험', 9),
#  ('사회', 9),
#  ('도전', 9),
#  ('경남', 9),
#  ('도시', 9),
#  ('사과', 9),
#  ('탐방', 8),
#  ('동물', 8),
#  ('방역', 8),
#  ('일', 8),
#  ('불', 8),
#  ('전국', 8),
#  ('게임', 8),
#  ('씨', 8),
# ...

# %%
df_mask = np.array(Image.open('/content/drive/MyDrive/DNA1조/D.N.A 하반기 1조/오산시 분석대회/이파리리.png'))
df_mask
# Out:
# array([[[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
# ...

# %%
wc = WordCloud(background_color='white', max_words=150, stopwords=my_stopword, mask=df_mask,font_path='NanumBarunGothic')
wc = wc.generate(df4)  # 데이터 불러와서 워드클라우드 옵션 지정
wc

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(16,16))
plt.imshow(wc)
plt.axis('off')  # 축 없이!
plt.show()

# %% [markdown]
# # 임대농장

# %%
df5 = pd.read_excel("/content/drive/MyDrive/data/네이버뉴스_임대농장_2021-09-28_21시24분.xlsx")
df5
# Out:
#      Unnamed: 0  ...                                                url
# 0             0  ...  http://weekly.chosun.com/client/news/viw.asp?n...
# 1             1  ...  http://www.newsfarm.co.kr/news/articleView.htm...
# 2             2  ...  http://www.kado.net/news/articleView.html?idxn...
# 3             3  ...  http://www.kmaeil.com/news/articleView.html?id...
# 4             4  ...  https://www.siminilbo.co.kr/news/newsview.php?...
# ..          ...  ...                                                ...
# 995         995  ...                http://www.hyunchuk.co.kr/news/7400
# 996         996  ...  http://www.kgnews.co.kr/news/articleView.html?...
# 997         997  ...  https://news.naver.com/main/read.naver?mode=LS...
# 998         998  ...  http://news.kbs.co.kr/news/NewsView.do?SEARCH_...
# 999         999  ...  http://www.dailian.co.kr/news/news_view.htm?id...
#
# [1000 rows x 3 columns]

# %%
df5.dropna(inplace = True)
df5.drop_duplicates(['title'], keep = 'last')
# Out:
#      Unnamed: 0  ...                                                url
# 0             0  ...  http://weekly.chosun.com/client/news/viw.asp?n...
# 1             1  ...  http://www.newsfarm.co.kr/news/articleView.htm...
# 2             2  ...  http://www.kado.net/news/articleView.html?idxn...
# 3             3  ...  http://www.kmaeil.com/news/articleView.html?id...
# 4             4  ...  https://www.siminilbo.co.kr/news/newsview.php?...
# ..          ...  ...                                                ...
# 995         995  ...                http://www.hyunchuk.co.kr/news/7400
# 996         996  ...  http://www.kgnews.co.kr/news/articleView.html?...
# 997         997  ...  https://news.naver.com/main/read.naver?mode=LS...
# 998         998  ...  http://news.kbs.co.kr/news/NewsView.do?SEARCH_...
# 999         999  ...  http://www.dailian.co.kr/news/news_view.htm?id...
#
# [607 rows x 3 columns]

# %%
import numpy as np
df_5 = np.array(df5['title'].tolist())
df5 = " ".join(df_5)

# %%
from konlpy.tag import Okt 
twitter_tag = Okt()
def my_tokenizer(doc):
    return [token for token, pos in twitter_tag.pos(doc) if pos in ['Noun']]
df5_doc = my_tokenizer(df5)

# %%
print(df5_doc, end = '')
# Out:
# ['요양원', '대신', '농장', '케어', '김포시', '치유', '농업', '및', '농기', '임대', '사업', '현장', '행정', '실시', '영월', '영월', '서강', '보존', '본부', '포도', '체험', '농장', '호평', '김포시', '농업', '기술', '센터', '소장', '치유', '농업', '및', '농기', '임대', '사업', '현장', '행정', '실시', '함양', '청년', '농업인', '경영', '실습', '임대', '농장', '딸기', '재배', '시작', '청년', '농업인', '경영', '실습', '임대', '농장', '본격', '운영', '대구', '지역', '문제해결', '플랫폼', '청도', '청년', '농장', '주', '육성', '프로젝트', '입문', '과정', '진행', '귀농', '귀촌', '명품', '표고버섯', '농장', '나종철', '대표', '신원식', '전북', '농축', '산', '식품', '국장', '김제시', '농기', '임대', '사업', '소', '현장', '방문', '신원식', '농축', '산', '식품', '국장', '김제', '농기', '임대', '사업', '소', '방문', '신안군', '청년', '농업', '농업인', '경영', '실습', '임대', '농장', '지원', '눈길', '제주', '농지', '체험', '농장', '빙자', '부동산', '투기', '연', '기고', '청년', '농업인', '육성', '위', '경영', '실습', '임대', '농장', '조성', '추진', '김해시', '청년', '농업인', '경영', '실습', '임대', '농장', '운영', '본격', '김해시', '청년', '농업인', '경영', '실습', '임대', '농장', '준공', '김해시', '브리핑', '청년', '농업인', '경영', '실습', '임대', '농장', '준공', '등', '김포시', '경영', '실습', '임대', '농장', '임차', '청년', '농업', '
# ...

# %%
#빈도 사전 만들기
df_cnt5 = {}
for word in df4_doc:
    df_cnt5[word] = df_cnt5.get(word, 0) + 1

sorted_word_count = sorted(df_cnt4, key= df_cnt4.get, reverse=True)
#sorted_word_count 
print("빈도수가 많은 상위 30개:")
for key in sorted_word_count[:30]: 
    print(f'{repr(key)}: {df_cnt5[key]}', end=', ')
# Out:
# 빈도수가 많은 상위 30개:
# '청년': 62, '여성': 55, '대표': 53, '동물농장': 47, '외국인': 42, '농업': 41, '발견': 35, '실종': 33, '노동자': 31, '농촌': 29, '농부': 28, '야생': 27, '진드기': 27, '사망': 27, '근로자': 26, '귀농': 26, '부산': 25, '국회': 25, '남성': 24, '살해': 21, '인간': 20, '국내': 20, '회장': 19, '호주': 19, '첫': 19, '감염': 19, '돈': 18, '채': 18, '주': 18, '알': 18,

# %%
#불용어 사전 정리 후 재정의
my_stopword = ['임대 농장','농장','주말','위','명','코로나','시청률','오케이 광자매','주말드라마 한번다녀왔습니다','도','속','등','오케이','광자매','광','자매','로','홍은희','전혜빈','원희','차','농','청','토','확','중','철','곳','재','조사','법',
               '수','세','기','개','제','축구','프로그램','백신','슈퍼맨','것','윤주상','및','외','주말드라마 한번다녀왔습니다','한번다녀왔습니다 지상파'] 
result = [word for word in df4_doc if word not in my_stopword] 
#불용어 사전 제거 후 단어 빈도 사전 만들기
df_cnt5 = {}
for word in result:
    df_cnt5[word] = df_cnt5.get(word, 0) + 1
sorted_word_count = sorted(df_cnt5, key= df_cnt5.get, reverse=True)
#sorted_word_count 
print("빈도수가 많은 상위 30개:")
for key in sorted_word_count[:30]: 
    print(f'{repr(key)}: {df_cnt5[key]}', end=', ')
# Out:
# 빈도수가 많은 상위 30개:
# '청년': 62, '여성': 55, '대표': 53, '동물농장': 47, '외국인': 42, '농업': 41, '발견': 35, '실종': 33, '노동자': 31, '농촌': 29, '농부': 28, '야생': 27, '진드기': 27, '사망': 27, '근로자': 26, '귀농': 26, '부산': 25, '국회': 25, '남성': 24, '살해': 21, '인간': 20, '국내': 20, '회장': 19, '호주': 19, '첫': 19, '감염': 19, '돈': 18, '채': 18, '주': 18, '알': 18,

# %%
ko = nltk.Text(result, name='임대농장')
data5 = ko.vocab().most_common(150)
data5
# Out:
# [('청년', 62),
#  ('여성', 55),
#  ('대표', 53),
#  ('동물농장', 47),
#  ('외국인', 42),
#  ('농업', 41),
#  ('발견', 35),
#  ('실종', 33),
#  ('노동자', 31),
#  ('농촌', 29),
#  ('농부', 28),
#  ('야생', 27),
#  ('진드기', 27),
#  ('사망', 27),
#  ('근로자', 26),
#  ('귀농', 26),
#  ('부산', 25),
#  ('국회', 25),
#  ('남성', 24),
#  ('살해', 21),
#  ('인간', 20),
#  ('국내', 20),
#  ('회장', 19),
#  ('호주', 19),
#  ('첫', 19),
#  ('감염', 19),
#  ('돈', 18),
#  ('채', 18),
#  ('주', 18),
#  ('알', 18),
#  ('교회', 18),
#  ('미래', 18),
#  ('동료', 17),
#  ('완주', 17),
#  ('돼지', 17),
#  ('현장', 17),
#  ('꿈', 16),
#  ('일', 16),
#  ('농업인', 15),
#  ('남', 15),
#  ('검거', 15),
#  ('뱀', 15),
#  ('의', 15),
#  ('안산', 15),
#  ('귀촌', 15),
#  ('사람', 14),
#  ('시신', 14),
#  ('종합', 14),
#  ('농사', 14),
#  ('선거', 13),
#  ('버섯', 13),
#  ('창업', 13),
#  ('교육', 13),
#  ('출마', 13),
#  ('동물복지', 13),
#  ('농막', 13),
#  ('집', 13),
#  ('확진', 13),
#  ('화보', 13),
#  ('이야기', 12),
#  ('최고', 12),
#  ('한국', 12),
#  ('브리핑', 12),
#  ('비단', 12),
#  ('산업', 12),
#  ('전', 12),
# ...

# %%
wc = WordCloud(background_color='white', max_words=150, stopwords=my_stopword, mask=df_mask,font_path='NanumBarunGothic')
wc = wc.generate(df5)  # 데이터 불러와서 워드클라우드 옵션 지정
wc

# %%
plt.figure(figsize=(16,16))
plt.imshow(wc)
plt.axis('off')  # 축 없이!
plt.show()

# %% [markdown]
# # 오산시

# %%
df6 = pd.read_excel("/content/drive/MyDrive/네이버뉴스_오산시_2021-10-04_13시26분.xlsx")
df6
# Out:
#       Unnamed: 0  ...                                                url
# 0              0  ...  http://www.weeklytoday.com/news/articleView.ht...
# 1              1  ...  https://www.asiatoday.co.kr/view.php?key=20211...
# 2              2  ...  http://news.heraldcorp.com/view.php?ud=2021100...
# 3              3  ...  https://www.pressian.com/pages/articles/202110...
# 4              4  ...  http://www.gukjenews.com/news/articleView.html...
# ...          ...  ...                                                ...
# 2995        2995  ...  http://moneys.mt.co.kr/news/mwView.php?no=2021...
# 2996        2996  ...  http://www.nspna.com/news/?mode=view&newsid=50...
# 2997        2997  ...  http://www.m-i.kr/news/articleView.html?idxno=...
# 2998        2998  ...  http://www.incheonilbo.com/news/articleView.ht...
# 2999        2999  ...  http://www.joongdo.co.kr/web/view.php?key=2021...
#
# [3000 rows x 3 columns]

# %%
df6.dropna(inplace = True)
df6.drop_duplicates(['title'], keep = 'last')
# Out:
#       Unnamed: 0  ...                                                url
# 0              0  ...  http://www.weeklytoday.com/news/articleView.ht...
# 1              1  ...  https://www.asiatoday.co.kr/view.php?key=20211...
# 2              2  ...  http://news.heraldcorp.com/view.php?ud=2021100...
# 3              3  ...  https://www.pressian.com/pages/articles/202110...
# 4              4  ...  http://www.gukjenews.com/news/articleView.html...
# ...          ...  ...                                                ...
# 2995        2995  ...  http://moneys.mt.co.kr/news/mwView.php?no=2021...
# 2996        2996  ...  http://www.nspna.com/news/?mode=view&newsid=50...
# 2997        2997  ...  http://www.m-i.kr/news/articleView.html?idxno=...
# 2998        2998  ...  http://www.incheonilbo.com/news/articleView.ht...
# 2999        2999  ...  http://www.joongdo.co.kr/web/view.php?key=2021...
#
# [1821 rows x 3 columns]

# %%
import numpy as np
df_6 = np.array(df6['title'].tolist())
df6 = " ".join(df_6)

# %%
# !pip install konlpy
# Out:
# ...
#      |████████████████████████████████| 19.4 MB 6.9 MB/s
# ...
#      |████████████████████████████████| 448 kB 49.4 MB/s
# ...
#      |████████████████████████████████| 86 kB 4.7 MB/s
# ...
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.6.3
#     Uninstalling beautifulsoup4-4.6.3:
#       Successfully uninstalled beautifulsoup4-4.6.3
# ...

# %%
from konlpy.tag import Okt 
twitter_tag = Okt()
def my_tokenizer(doc):
    return [token for token, pos in twitter_tag.pos(doc) if pos in ['Noun']]
df6_doc = my_tokenizer(df6)

# %%
print(df6_doc, end = '')
# Out:
# ['오산시', '제', '노인', '날', '기념', '표창', '수여', '오산시', '외국인', '체납', '징수', '아파트', '값', '급등', '오산', '지경', '부동산', '오산', '소식', '오산시', '제', '차', '경기도', '재난', '기본소득', '신청', '시작', '등', '오산시', '제', '노인', '날', '기념', '표창', '수여', '제주', '리조트', '느낌', '집안', '평상', '오산시', '주택', '매매', '홈즈', '어제', '오산시', '외국인', '체납', '특별', '정리', '오산시', '댕댕', '퍼스', '널', '트레이닝', '개최', '오산시', '개별', '공동', '주택', '가격', '결정', '공시', '및', '이의신청', '안내', '한신대', '오산시', '오산', '크리에이터', '홍보', '대사', '기', '발대식', '경기', '신규', '확진', '명', '오산시', '정신병원', '명', '발생', '오산시', '의회', '노인', '날', '유공', '표창장', '수여', '오산시', '핀란드', '에스포', '시', '교육', '협력', '업무', '협약', '체결', '오산시', '오색', '시장', '전통', '시장', '경쟁력', '강화', '투입', '오산시', '핀란드', '에스포', '시', '교류', '협력', '업무', '협약', '체결', '오산시', '경기도', '차', '재난', '기본소득', '신청', '접수', '시작', '곽상욱', '오산시', '학습', '도시', '연맹', '동의', '추대', '오산시', '오산', '민주', '시민', '교육', '성과', '유회', '료', '오산시', '오색', '시장', '문화', '관광', '시장', '육성', '빅데이터', '더욱', '세밀', '오산', '청년', '삶', '여개', '사업', '오산시', '직원', '역량', '강화', '위', '계약', '심사', '직무', '
# ...

# %%
#빈도 사전 만들기
df_cnt6 = {}
for word in df6_doc:
    df_cnt6[word] = df_cnt6.get(word, 0) + 1

sorted_word_count = sorted(df_cnt6, key= df_cnt6.get, reverse=True)
#sorted_word_count 
print("빈도수가 많은 상위 30개:")
for key in sorted_word_count[:30]: 
    print(f'{repr(key)}: {df_cnt6[key]}', end=', ')
# Out:
# 빈도수가 많은 상위 30개:
# '오산시': 2889, '오산': 321, '도시': 253, '지원': 252, '개최': 245, '교육': 213, '센터': 204, '등': 202, '시민': 199, '운영': 194, '제': 187, '실시': 174, '사업': 171, '문화': 170, '회': 170, '복지': 157, '모집': 149, '코로나': 144, '소식': 135, '명': 133, '청년': 128, '협약': 114, '의회': 108, '선정': 107, '사회': 106, '아동': 104, '지역': 100, '학교': 99, '청소년': 95, '개': 92,

# %%
#불용어 사전 정리 후 재정의
my_stopword = ['등', '개', '오산시', '오산', '수원뉴스 오산시', 'tv 수원뉴스', '수원', '경기', '실시', '개최', '지원', '모집', '운영',
               '위한', '비대면', '확대', '진행', '오산시의회', '코로나19', '속보 코로나', '곽상욱', '곽상욱 오산시장', '곽상욱오산시장', '도시', '코로나'
               ,'2021', '2021년', '소식', '성료', '오산시장', '오산 시장', '나서', '추진', '선정', '속보 확진자', '속보', '확진자'
               ,'업무', '업무 협약', '업무협약', '업무협약체결', '업무 협약 체결', '업무협약 체결', '경기도',  'tv수원뉴스', 'tv 수원 뉴스'
               ,'tv', '뉴스', '체결', '교란', '베트남 꽝남성', '베트남', '베트남꽝남성', '수강생', 'NH농협오산시지부', '추석연휴', '재산세' ,'정기분재산세',
               '정기분 재산세','추석', '수원뉴스', '수원 뉴스', 'NH농협', '오산시지부', '문화도시', '스마트도시',' 운암뜰AI스마트시티',
               'AI스마트시티', '스마트시티'] 
result = [word for word in df6_doc if word not in my_stopword] 
#불용어 사전 제거 후 단어 빈도 사전 만들기
df_cnt6 = {}
for word in result:
    df_cnt6[word] = df_cnt6.get(word, 0) + 1
sorted_word_count = sorted(df_cnt6, key= df_cnt6.get, reverse=True)
#sorted_word_count 
print("빈도수가 많은 상위 30개:")
for key in sorted_word_count[:30]: 
    print(f'{repr(key)}: {df_cnt6[key]}', end=', ')
# Out:
# 빈도수가 많은 상위 30개:
# '교육': 213, '센터': 204, '시민': 199, '제': 187, '사업': 171, '문화': 170, '회': 170, '복지': 157, '명': 133, '청년': 128, '협약': 114, '의회': 108, '사회': 106, '아동': 104, '지역': 100, '학교': 99, '청소년': 95, '의원': 83, '관리': 82, '온라인': 81, '건강': 81, '시설': 80, '위': 78, '대상': 78, '환경': 75, '주민': 75, '기탁': 74, '시장': 72, '사랑': 71, '기관': 70,

# %%
import nltk
from wordcloud import WordCloud
from PIL import Image

# %%
pip install wordcloud

# %%
ko = nltk.Text(result, name='오산시')
data6 = ko.vocab().most_common(150)
data6
# Out:
# [('교육', 213),
#  ('센터', 204),
#  ('시민', 199),
#  ('제', 187),
#  ('사업', 171),
#  ('문화', 170),
#  ('회', 170),
#  ('복지', 157),
#  ('명', 133),
#  ('청년', 128),
#  ('협약', 114),
#  ('의회', 108),
#  ('사회', 106),
#  ('아동', 104),
#  ('지역', 100),
#  ('학교', 99),
#  ('청소년', 95),
#  ('의원', 83),
#  ('관리', 82),
#  ('온라인', 81),
#  ('건강', 81),
#  ('시설', 80),
#  ('위', 78),
#  ('대상', 78),
#  ('환경', 75),
#  ('주민', 75),
#  ('기탁', 74),
#  ('시장', 72),
#  ('사랑', 71),
#  ('기관', 70),
#  ('날', 68),
#  ('점검', 67),
#  ('학습', 65),
#  ('비대', 64),
#  ('취약', 62),
#  ('및', 61),
#  ('강화', 61),
#  ('가정', 61),
#  ('운암', 60),
#  ('뜰', 60),
#  ('마을', 58),
#  ('교통', 57),
#  ('기념', 56),
#  ('개발', 56),
#  ('지정', 56),
#  ('사례', 55),
#  ('아파트', 54),
#  ('회의', 54),
#  ('협력', 53),
#  ('협의', 53),
#  ('오색', 51),
#  ('경제', 50),
#  ('서비스', 50),
#  ('우수', 50),
#  ('차', 49),
#  ('프로그램', 49),
#  ('공모전', 49),
#  ('배달', 49),
#  ('안전', 49),
#  ('학생', 49),
#  ('시티', 48),
#  ('정책', 48),
#  ('이음', 48),
#  ('개선', 48),
#  ('스마트', 46),
# ...

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 37 not upgraded.
# Need to get 9,604 kB of archives.
# After this operation, 29.5 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 fonts-nanum all 20170925-1 [9,604 kB]
# Fetched 9,604 kB in 1s (7,215 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package fonts-nanum.
# ...

# %%
df_mask = np.array(Image.open('/content/drive/MyDrive/이파리리.png'))
df_mask
# Out:
# array([[[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
# ...

# %%
wc = WordCloud(background_color='white', max_words=150, stopwords=my_stopword, mask=df_mask,font_path='NanumBarunGothic')
wc = wc.generate(df6)  # 데이터 불러와서 워드클라우드 옵션 지정
wc

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(16,16))
plt.imshow(wc)
plt.axis('off')  # 축 없이!
plt.show()
